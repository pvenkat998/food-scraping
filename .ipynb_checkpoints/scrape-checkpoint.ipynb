# %%
from selenium import webdriver
import os
from util_selenium import *
import csv
import time

import pprint
import urllib.error
import urllib.request

def download_file(url, dst_path):
    try:
        with urllib.request.urlopen(url) as web_file:
            data = web_file.read()
            with open(dst_path, mode='wb') as local_file:
                local_file.write(data)
    except urllib.error.URLError as e:
        print(e)

class KurashiruDetail:
    def __init__(self, driver, page_list, page_num = 707, wait_time = 2):
        self.account = 'koeruqin1998@gmail.com'
        self.password = 'tengteng98'
        self.base_url = 'https://www.kurashiru.com/video_categories/1?page='

        self.page_num = page_num
        self.url_list = []

        self.driver = driver
        self.wait_time = wait_time

        self.mymail = 'koeruqin1998@gmail.com'
        self.mypass = 'tengteng98'

        self.pagelist = page_list

        self.path_dataset = "./data"
        self.saved_num = 0

        self.login(self.mymail, self.mypass)

    
    def login(self, mymail, mypass):

        mydriverget(self.driver, self.base_url + "1", self.wait_time)
        login_but = self.driver.find_element_by_xpath('//*[@id="header_app"]/div/div[3]/span/div[2]')
        mydriverclick(login_but, self.driver, self.wait_time)

        field_login = self.driver.find_element_by_xpath('//*[@id="sessions_new"]/div/div[2]/div[1]/div/input')
        field_pass = self.driver.find_element_by_xpath('//*[@id="sessions_new"]/div/div[2]/div[2]/div/input')

        field_login.send_keys(self.mymail)
        field_pass.send_keys(self.mypass)

        login2 = self.driver.find_element_by_xpath('//*[@id="sessions_new"]/div/div[2]/button[1]/div')
        mydriverclick(login2, self.driver, self.wait_time)
    
    def scrape_all_url(self):
        self.url_list = []
        for j in range(self.page_num):
            print(j)

            newurl = self.base_url + str(j)

            mydriverget(self.driver, newurl, self.wait_time)

            ellist = mytrygetel(self.driver.find_elements_by_xpath, '//*[@id="partial_spa"]/div[1]/div/div/main/div[2]/div/li[*]/div/a')

            newlist = []

            for i in range(len(ellist)):
                self.url_list.append(ellist[i].get_attribute('href'))
                newlist.append(ellist[i].get_attribute('href'))
            
            with open("kurasiru_url1.txt", "a") as f:
                for url_ in newlist:
                    f.write(url_ + '\n')

            print("added ", len(ellist), " urls")
            if len(self.url_list) > 0:
                print(self.url_list[-1]) 

        return self.url_list

    def get_detail(self):
        #for page in self.pagelist:
        le=len(self.pagelist)
        for i in range(le):
            page=self.pagelist[le-1-i]
            uuid = os.path.basename(page)

            datapath = os.path.join(self.path_dataset, uuid)
            
            if os.path.exists(datapath):
                continue
            else:
                if not os.path.exists(datapath):
                    os.mkdir(datapath)
                    print("make dir: ", datapath)

                mydriverget(self.driver, page, self.wait_time)

                #ページが存在しない可能性も
                try:
                    url_video = self.driver.find_element_by_xpath('//*[@id="videos_show"]/div/main/article[1]/article/div[1]/div/video/source[2]').get_attribute('src')
                except:
                    os.rmdir(datapath)
                    continue

                with open(os.path.join(datapath, "video_url.txt"), "w") as f:
                    f.write(url_video)
                
                url_thumb = self.driver.find_element_by_xpath('//*[@id="videos_show"]/div/main/article[1]/article/div[1]/div/video').get_attribute('poster')

                download_file(url_thumb, os.path.join(datapath, "thumbnail.jpg"))

                str_title = self.driver.find_element_by_xpath('//*[@id="videos_show"]/div/main/article[1]/article/div[2]/h1').get_attribute('innerHTML')

                with open(os.path.join(datapath, "title.txt"), "w", encoding="utf-8") as f:
                    f.write(str_title)

                numeric = self.driver.find_elements_by_xpath('//*[@id="videos_show"]/div/main/article[1]/article/div[3]/div[1]/div[*]/span[2]')

                with open(os.path.join(datapath, "numeric.txt"), "w") as f:

                    for data in numeric:
                        f.write(data.get_attribute('innerHTML') + "\n")
                
                ingredients = self.driver.find_elements_by_xpath('//*[@id="videos_show"]/div/main/article[1]/article/section[1]/ul/li[*]/span[1]')
                
                with open(os.path.join(datapath, "ingredients.txt"), "w") as f:
                    for g in ingredients:
                        f.write(g.get_attribute('innerHTML') + "\n")

                instructions = self.driver.find_elements_by_xpath('//*[@id="videos_show"]/div/main/article[1]/article/section[2]/ol/li[*]/span[2]')
                
                with open(os.path.join(datapath, "instructions.txt"), "w", encoding="utf-8") as f:
                    for i in instructions:
                        f.write(i.get_attribute('innerHTML') + "\n")
                
                path_tsukurepo = os.path.join(datapath, "tsukurepo")
                if not os.path.exists(path_tsukurepo):
                    os.mkdir(path_tsukurepo)
                #//*[@id="videos_show"]/div/main/div/article[1]/div/div[1]/div/div[1]/div/img
                tsukurepo = self.driver.find_elements_by_xpath('//*[@id="videos_show"]/div/main/div/article[1]/div/div[1]/div[*]/div[1]/div/img')

                for i in range(len(tsukurepo)):
                    try:
                        download_file(tsukurepo[i].get_attribute('src'), os.path.join(path_tsukurepo, "img" + str(i) + ".jpg"))
                    except:
                        pass

                self.saved_num += 1
                print("processed ", self.saved_num, " ...")

def main():
    with open("./kurasiru_url.txt", "r") as f:
        datalist = f.read().split()

   
    driver = webdriver.Chrome()

    kurasiru = KurashiruDetail(driver, datalist)
    kurasiru.get_detail()


if __name__ == "__main__":
    main()
# Out:
# make dir:  ./data\9f910b3d-e13f-43d5-a9a0-d0680adc4ae4
# make dir:  ./data\9eb8c2c7-ad69-4564-bc7f-08733dd9542e
# processed  1  ...
# make dir:  ./data\48c2fed2-8498-481e-a204-755123ef899d
# processed  2  ...
# make dir:  ./data\fdd7e307-727f-48c6-ac8c-330813414b8c
# processed  3  ...
# make dir:  ./data\ffb122ca-4184-46bc-bef3-1202a1c1d2ef
# processed  4  ...
# make dir:  ./data\8c5fc106-2c41-49ca-8efd-36b1890b7524
# processed  5  ...
# make dir:  ./data\99abc176-5a4a-4364-a23c-e68874694d14
# processed  6  ...
# make dir:  ./data\5064b939-ee60-4973-a414-7480ffaadc7c
# processed  7  ...
# make dir:  ./data\7c11a253-0d5f-40fe-8821-8599cdce2d28
# processed  8  ...
# make dir:  ./data\60276006-c967-40d4-b423-70436ba746dc
# processed  9  ...
# make dir:  ./data\32a2e827-213c-43be-bee9-8e937e98a449
# processed  10  ...
# make dir:  ./data\c2028f65-a8ac-4b6c-8081-6a40a87acc78
# processed  11  ...
# make dir:  ./data\c819c8b2-6673-4e2a-9e7c-f8ea56b68602
# make dir:  ./data\be4bc2be-0dbb-40c1-859a-3dc854bdb1b7
# processed  142  ...
# make dir:  ./data\3a2cbf2e-290d-4778-b686-8cc171af3efb
# processed  143  ...
# make dir:  ./data\11d7e730-a286-4272-b6e4-0debe5e2fa2e
# processed  144  ...
# make dir:  ./data\6ecc290d-b3a7-40d1-bc3a-800f7ac2c50a
# processed  145  ...
# make dir:  ./data\d815e4a8-5a47-4304-9975-b86594c04604
# processed  146  ...
# make dir:  ./data\18ab7f5e-58eb-4501-a466-d4f8dc629a96
# processed  147  ...
# make dir:  ./data\f7d94909-d3e2-4eb0-8838-a60edc674ccd
# processed  148  ...
# make dir:  ./data\22ee8617-37eb-4598-8a87-303c0ef9838a
# processed  149  ...
# make dir:  ./data\e9f034a0-6d28-41c7-84d8-00d5e974cd07
# processed  150  ...
# make dir:  ./data\579409fd-876b-486b-a63d-019b1de6b984
# processed  151  ...
# make dir:  ./data\545f654a-c4b8-4bb8-b606-786e4059364d
# processed  152  ...
# make dir:  ./data\8f6e4072-0de7-460e-bb4c-cf16bdc6b0ec
# processed  153  ...
# make dir:  ./data\a0afe989-b3de-47c4-81db-b4bcf9d69046
# make dir:  ./data\d9213dae-fc32-4f9b-bf2f-5d0a7465f597
# processed  154  ...
# make dir:  ./data\eb2dd9a8-899c-438f-b560-de9ace06df26
# processed  155  ...
# make dir:  ./data\18720165-5e20-4bff-8a5a-8d4cd912b1de
# processed  156  ...
# make dir:  ./data\de06fbbc-2a08-4017-951a-28c666d4d6fd
# processed  157  ...
# make dir:  ./data\90b3ea8c-e106-4133-8b95-1dd0fa980624
# processed  158  ...
# make dir:  ./data\1d720772-b53a-4016-a186-859730ca4a57
# processed  159  ...
# make dir:  ./data\43422cff-221a-4019-8b38-1a137ae75608
# processed  160  ...
# make dir:  ./data\99bd3f70-1d4d-4cde-bb54-288eee770ca3
# processed  161  ...
# make dir:  ./data\bd5a92c3-0fe5-4109-9d0f-23237124605c
# processed  162  ...
# make dir:  ./data\2c8da8cc-0859-44ae-967a-04b83a63ded0
# processed  163  ...
# make dir:  ./data\cbbe59ef-fb34-43c2-893c-87cb7c3ce39f
# processed  164  ...
# make dir:  ./data\28a57296-6fe1-4f38-95cc-ccc15e425fad
# processed  165  ...
# make dir:  ./data\c3fde7df-4c58-44cb-be19-3232c22fedee
# processed  166  ...
# make dir:  ./data\16acfff4-b700-403e-a424-ec8f28769846
# processed  167  ...
# make dir:  ./data\a4872857-dc08-401b-8028-0ca3eef11bff
# processed  168  ...
# make dir:  ./data\4b90611d-999d-4b27-8e62-e974937caecc
# processed  169  ...
# make dir:  ./data\cc45f815-10b6-460e-b383-127a03046625
# processed  170  ...
# make dir:  ./data\4aeb50dc-4baa-4e1d-9eb9-d4d2940e756e
# processed  171  ...
# make dir:  ./data\bfe4d322-1151-4155-87fc-9a6c04d2c416
# processed  172  ...
# make dir:  ./data\393960f3-9d94-40c7-8c43-d9b36b294cf4
# processed  173  ...
# processed  205  ...
# make dir:  ./data\0bb69705-fbe4-48a8-b291-d454ec572709
# processed  206  ...
# make dir:  ./data\0bb662db-cb1e-4166-b1eb-2d41e6add008
# processed  207  ...
# make dir:  ./data\b86da003-77ee-47cd-9c1a-8bef83d51c29
# processed  208  ...
# make dir:  ./data\6f48afd8-4fb0-40c6-adb9-382ec419dbbc
# processed  209  ...
# make dir:  ./data\f85aa8cd-9114-4fd8-9835-bdb9f348f220
# processed  210  ...
# make dir:  ./data\7373307b-3463-44ff-8ca4-b8db9b988943
# processed  211  ...
# make dir:  ./data\81f18fd5-01bf-4c6e-ae20-b20a6b4a2397
# processed  212  ...
# make dir:  ./data\4a60d75d-6a55-4479-8ee3-195b38508d1a
# processed  213  ...
# make dir:  ./data\e561e6e7-1695-40f2-9cb5-89ac5819cf16
# processed  214  ...
# make dir:  ./data\186edc5a-c97e-46b9-a48d-bc7728e462aa
# processed  215  ...
# make dir:  ./data\656c791a-cd74-4d69-9958-1faee1571b30
# processed  216  ...
# make dir:  ./data\e9d3e91f-cee7-403c-8679-a67bd6dda03e
# processed  217  ...
# make dir:  ./data\4f7c861d-4c23-4837-ab04-63fc562ee712
# processed  218  ...
# make dir:  ./data\1d2e7861-36dc-454a-b936-19b52f31bdc3
# processed  219  ...
# make dir:  ./data\1eacc1d6-0b91-4c84-a036-e8f69adba3b1
# processed  220  ...
# make dir:  ./data\f6de9d15-f83a-4e88-88a5-4ceda01f85df
# processed  221  ...
# make dir:  ./data\4f9ecd73-23b8-4cca-8bd0-40f4e47a40ac
# processed  222  ...
# make dir:  ./data\5a5df01a-086e-4dc9-9f3d-6c85b2fa086a
# processed  223  ...
# make dir:  ./data\a2e77e26-5d7d-4fd6-aa46-dc3cf54bedbb
# processed  224  ...
# make dir:  ./data\a5c486b3-df5c-4d8c-8dff-329c07435132
# processed  225  ...
# make dir:  ./data\011ecd78-e262-4aa8-a991-6857f114177a
# processed  226  ...
# make dir:  ./data\dcdf5e0d-28c2-41a5-b770-480a3e1e5ddf
# processed  227  ...
# make dir:  ./data\22ecdbab-3a9b-403a-8649-34c0b0a8d856
# processed  228  ...
# make dir:  ./data\5d350735-05f6-448f-ad02-33cb66b88d9d
# processed  229  ...
# make dir:  ./data\1225d784-8e1e-406d-a7c0-79291969dc91
# processed  230  ...
# make dir:  ./data\1c3f8ae2-3a8e-4d3c-9270-65930f1bd5f3
# processed  231  ...
# make dir:  ./data\71173f85-0274-4dcf-92f3-26defe131280
# processed  232  ...
# make dir:  ./data\093698f8-03ac-45ab-b2f4-8975d6b5ed25
# processed  233  ...
# make dir:  ./data\a6fbb8f3-8dda-40d5-bb77-15ca8ffd8405
# processed  234  ...
# make dir:  ./data\7371ab2a-3a0e-4377-b1b6-3bfe1dd335c9
# processed  235  ...
# make dir:  ./data\293b813c-2ea5-49dd-aaec-efcc469ce2f9
# processed  236  ...
# make dir:  ./data\fa48cd4b-d838-46ab-8446-2340a2f7a1a9
# processed  237  ...
# make dir:  ./data\e9a8a0bc-0347-44fd-9cd5-199046488b30
# processed  238  ...
# make dir:  ./data\490bf3c1-8305-4c39-93cb-2d5ad9bb31e7
# processed  239  ...
# make dir:  ./data\5cec4946-ca9f-42bc-9173-add779576ac0
# processed  240  ...
# make dir:  ./data\4dcfb3d4-3692-475c-a922-7a282731dfc7
# processed  241  ...
# make dir:  ./data\d7256dc8-80fb-47f3-abd4-cf229a74e002
# processed  242  ...
# make dir:  ./data\ba6889d7-d3d5-4ac1-a16e-a4d5cf529e41
# processed  243  ...
# make dir:  ./data\3a9ce30a-8154-4420-a1a2-b3addfba7363
# processed  244  ...
# make dir:  ./data\8871f5f2-3420-4b87-adee-e2a593cc6d1b
# processed  245  ...
# make dir:  ./data\05bda8f4-6557-4238-8e0f-e68ae3d267bd
# processed  246  ...
# make dir:  ./data\5fe8334c-c500-428f-8493-6996633f295b
# processed  247  ...
# make dir:  ./data\386399b6-c486-448b-883a-b0b859283fbb
# processed  248  ...
# make dir:  ./data\1b76eb78-d042-4bba-9bfa-cba0782fd962
# processed  249  ...
# make dir:  ./data\194a7946-85cb-4692-a7ce-dd206e9eb884
# processed  250  ...
# make dir:  ./data\d5f4b5e8-8054-4a2e-8d9e-cc92a9d7280b
# processed  251  ...
# make dir:  ./data\d8bd9fd4-09ed-49a5-abdd-da030d2384b4
# processed  252  ...
# make dir:  ./data\cce8efc4-76c8-4425-a47c-c99f9fb16674
# processed  253  ...
# make dir:  ./data\816023ba-b9d5-4591-9c53-895c71ad1ec0
# processed  254  ...
# make dir:  ./data\37883f83-2f29-4266-a140-40be5b00940a
# processed  255  ...
# make dir:  ./data\2cc344c7-a2ee-4189-84d3-2c58a1fc2132
# processed  256  ...
# make dir:  ./data\1ec03e89-0246-41be-b959-036c550eb1f7
# processed  257  ...
# make dir:  ./data\c92d9080-4f75-456b-a1e1-0a2a2a8e283f
# processed  258  ...
# make dir:  ./data\31c69d8c-c509-4835-b7f1-f1d7791097e0
# processed  259  ...
# make dir:  ./data\72ed5af9-a17c-4cf6-bec1-bd080d604da2
# processed  260  ...
# make dir:  ./data\28ab75cd-023f-4fc6-bfb2-20d2915491c6
# -------------------------------------------------------------------------
# UnicodeEncodeError                      Traceback (most recent call last)
# <ipython-input-17-bc857390cc8b> in <module>
#     166
#     167 if __name__ == "__main__":
# --> 168     main()
#
# <ipython-input-17-bc857390cc8b> in main()
#     162
#     163     kurasiru = KurashiruDetail(driver, datalist)
# --> 164     kurasiru.get_detail()
#     165
#     166
#
# <ipython-input-17-bc857390cc8b> in get_detail(self)
#     118
#     119                 with open(os.path.join(datapath, "title.txt"), "w") as f:
# --> 120                     f.write(str_title)
#     121
#     122                 numeric = self.driver.find_elements_by_xpath('//*[@id="videos_show"]/div/main/article[1]/article/div[3]/div[1]/div[*]/span[2]')
#
# UnicodeEncodeError: 'cp932' codec can't encode character '\u2048' in position 7: illegal multibyte sequence
